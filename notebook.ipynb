# %%
import timm

model = timm.create_model('resnet50', pretrained=True)
model.eval();

# %%
import cv2
from render import show_images
from image_utils import center_crop, resize_shortest_edge

imgs = []

for file_path in ['jay.jpg', 'jays.jpg', 'tools.jpg', 'racecar.jpg']:
    img = cv2.imread(file_path)[..., ::-1]
    img = resize_shortest_edge(img, 384, interpolation='auto')
    img = center_crop(img, (384, 384))
    imgs.append(img)

show_images(imgs, per_row=4, imsize=(5, 5));

# %%
import torch
from prepare_input import prepare

inps = [prepare(img, model.default_cfg['mean'], model.default_cfg['std'])
        for img in imgs]

with torch.no_grad():
    out = torch.softmax(model(inps[0]), -1)[0].numpy()

# synsets at https://github.com/rwightman/pytorch-image-models/blob/master/results/imagenet_synsets.txt
# jay is 17
print(out.argmax())
# Out:
# 17

# %%
from torchvision.models.feature_extraction import get_graph_node_names
from pprint import pprint

train_nodes, eval_nodes = get_graph_node_names(model)

assert([t == e for t, e in zip(train_nodes, eval_nodes)])

pprint(train_nodes)
# Out:
# ['x',
#  'conv1',
#  'bn1',
#  'act1',
#  'maxpool',
#  'layer1.0.conv1',
#  'layer1.0.bn1',
#  'layer1.0.act1',
#  'layer1.0.conv2',
#  'layer1.0.bn2',
#  'layer1.0.act2',
#  'layer1.0.conv3',
#  'layer1.0.bn3',
#  'layer1.0.downsample.0',
#  'layer1.0.downsample.1',
#  'layer1.0.add',
#  'layer1.0.act3',
#  'layer1.1.conv1',
#  'layer1.1.bn1',
#  'layer1.1.act1',
#  'layer1.1.conv2',
#  'layer1.1.bn2',
#  'layer1.1.act2',
#  'layer1.1.conv3',
#  'layer1.1.bn3',
#  'layer1.1.add_1',
#  'layer1.1.act3',
#  'layer1.2.conv1',
#  'layer1.2.bn1',
#  'layer1.2.act1',
#  'layer1.2.conv2',
#  'layer1.2.bn2',
#  'layer1.2.act2',
#  'layer1.2.conv3',
#  'layer1.2.bn3',
#  'layer1.2.add_2',
#  'layer1.2.act3',
#  'layer2.0.conv1',
#  'layer2.0.bn1',
#  'layer2.0.act1',
#  'layer2.0.conv2',
#  'layer2.0.bn2',
#  'layer2.0.act2',
#  'layer2.0.conv3',
#  'layer2.0.bn3',
#  'layer2.0.downsample.0',
#  'layer2.0.downsample.1',
#  'layer2.0.add_3',
#  'layer2.0.act3',
#  'layer2.1.conv1',
#  'layer2.1.bn1',
#  'layer2.1.act1',
#  'layer2.1.conv2',
#  'layer2.1.bn2',
#  'layer2.1.act2',
#  'layer2.1.conv3',
#  'layer2.1.bn3',
#  'layer2.1.add_4',
#  'layer2.1.act3',
#  'layer2.2.conv1',
#  'layer2.2.bn1',
#  'layer2.2.act1',
#  'layer2.2.conv2',
#  'layer2.2.bn2',
#  'layer2.2.act2',
#  'layer2.2.conv3',
#  'layer2.2.bn3',
#  'layer2.2.add_5',
#  'layer2.2.act3',
#  'layer2.3.conv1',
#  'layer2.3.bn1',
#  'layer2.3.act1',
#  'layer2.3.conv2',
#  'layer2.3.bn2',
#  'layer2.3.act2',
#  'layer2.3.conv3',
#  'layer2.3.bn3',
#  'layer2.3.add_6',
#  'layer2.3.act3',
#  'layer3.0.conv1',
#  'layer3.0.bn1',
#  'layer3.0.act1',
#  'layer3.0.conv2',
#  'layer3.0.bn2',
#  'layer3.0.act2',
#  'layer3.0.conv3',
#  'layer3.0.bn3',
#  'layer3.0.downsample.0',
#  'layer3.0.downsample.1',
#  'layer3.0.add_7',
#  'layer3.0.act3',
#  'layer3.1.conv1',
#  'layer3.1.bn1',
#  'layer3.1.act1',
#  'layer3.1.conv2',
#  'layer3.1.bn2',
#  'layer3.1.act2',
#  'layer3.1.conv3',
#  'layer3.1.bn3',
#  'layer3.1.add_8',
#  'layer3.1.act3',
#  'layer3.2.conv1',
#  'layer3.2.bn1',
#  'layer3.2.act1',
#  'layer3.2.conv2',
#  'layer3.2.bn2',
#  'layer3.2.act2',
#  'layer3.2.conv3',
#  'layer3.2.bn3',
#  'layer3.2.add_9',
#  'layer3.2.act3',
#  'layer3.3.conv1',
#  'layer3.3.bn1',
#  'layer3.3.act1',
#  'layer3.3.conv2',
#  'layer3.3.bn2',
#  'layer3.3.act2',
#  'layer3.3.conv3',
#  'layer3.3.bn3',
#  'layer3.3.add_10',
#  'layer3.3.act3',
#  'layer3.4.conv1',
#  'layer3.4.bn1',
#  'layer3.4.act1',
#  'layer3.4.conv2',
#  'layer3.4.bn2',
#  'layer3.4.act2',
#  'layer3.4.conv3',
#  'layer3.4.bn3',
#  'layer3.4.add_11',
#  'layer3.4.act3',
#  'layer3.5.conv1',
#  'layer3.5.bn1',
#  'layer3.5.act1',
#  'layer3.5.conv2',
#  'layer3.5.bn2',
#  'layer3.5.act2',
#  'layer3.5.conv3',
#  'layer3.5.bn3',
#  'layer3.5.add_12',
#  'layer3.5.act3',
#  'layer4.0.conv1',
#  'layer4.0.bn1',
#  'layer4.0.act1',
#  'layer4.0.conv2',
#  'layer4.0.bn2',
#  'layer4.0.act2',
#  'layer4.0.conv3',
#  'layer4.0.bn3',
#  'layer4.0.downsample.0',
#  'layer4.0.downsample.1',
#  'layer4.0.add_13',
#  'layer4.0.act3',
#  'layer4.1.conv1',
#  'layer4.1.bn1',
#  'layer4.1.act1',
#  'layer4.1.conv2',
#  'layer4.1.bn2',
#  'layer4.1.act2',
#  'layer4.1.conv3',
#  'layer4.1.bn3',
#  'layer4.1.add_14',
#  'layer4.1.act3',
#  'layer4.2.conv1',
#  'layer4.2.bn1',
#  'layer4.2.act1',
#  'layer4.2.conv2',
#  'layer4.2.bn2',
#  'layer4.2.act2',
#  'layer4.2.conv3',
#  'layer4.2.bn3',
#  'layer4.2.add_15',
#  'layer4.2.act3',
#  'global_pool.pool',
#  'global_pool.flatten',
#  'fc.fc_weight',
#  'fc.fc_bias',
#  'fc.linear']

# %%
from torchvision.models.feature_extraction import create_feature_extractor
import random
import seaborn as sns
import matplotlib.pyplot as plt

return_nodes = ['layer1', 'layer2', 'layer3', 'layer4']

feat_ext = create_feature_extractor(model, return_nodes=return_nodes)

with torch.no_grad():
    out = feat_ext(inps[0])

fig, ax = plt.subplots(4, 5, figsize=(25, 20))

# Pick 4 random feature maps from each layer
for i, layer in enumerate(return_nodes):
    feat_maps = out[layer].numpy().squeeze(0)
    feat_maps = random.sample(list(feat_maps), 4)
    ax[i][0].imshow(imgs[0])
    ax[i][0].set_xticks([])
    ax[i][0].set_yticks([])
    for j, feat_map in enumerate(feat_maps):
        sns.heatmap(feat_map, ax=ax[i][j+1], cbar=False)
        ax[i][j+1].set_xticks([])
        ax[i][j+1].set_yticks([])
        ax[i][j+1].set_title(f'{layer}: ({feat_map.shape[0]} x {feat_map.shape[1]})')

# %%
model = timm.create_model('xcit_medium_24_p8_384_dist', pretrained=True)

model.eval()

inps = [prepare(img, model.default_cfg['mean'], model.default_cfg['std'])
        for img in imgs]

with torch.no_grad():
    out = torch.softmax(model(inps[0]), -1)[0].numpy()

# synsets at https://github.com/rwightman/pytorch-image-models/blob/master/results/imagenet_synsets.txt
# jay is 17
print(out.argmax())
# Out:
# 17

# %%
from timm.models.xcit import PositionalEncodingFourier

train_nodes, eval_nodes = get_graph_node_names(
    model, tracer_kwargs={'leaf_modules': [PositionalEncodingFourier]})

assert([t == e for t, e in zip(train_nodes, eval_nodes)])

pprint(train_nodes)
# Out:
# ['x',
#  'getattr_1',
#  'getitem',
#  'patch_embed.proj.0.0',
#  'patch_embed.proj.0.1',
#  'patch_embed.proj.1',
#  'patch_embed.proj.2.0',
#  'patch_embed.proj.2.1',
#  'patch_embed.proj.3',
#  'patch_embed.proj.4.0',
#  'patch_embed.proj.4.1',
#  'patch_embed.getattr_2',
#  'patch_embed.getitem_1',
#  'patch_embed.getattr_3',
#  'patch_embed.getitem_2',
#  'patch_embed.flatten',
#  'patch_embed.transpose',
#  'pos_embed',
#  'getattr_4',
#  'getitem_3',
#  'reshape',
#  'permute',
#  'add',
#  'pos_drop',
#  'blocks.0.blocks_0_gamma1',
#  'blocks.0.norm1',
#  'blocks.0.attn.getattr_5',
#  'blocks.0.attn.getitem_4',
#  'blocks.0.attn.getitem_5',
#  'blocks.0.attn.getitem_6',
#  'blocks.0.attn.qkv',
#  'blocks.0.attn.floordiv',
#  'blocks.0.attn.reshape_1',
#  'blocks.0.attn.permute_1',
#  'blocks.0.attn.getitem_7',
#  'blocks.0.attn.getitem_8',
#  'blocks.0.attn.getitem_9',
#  'blocks.0.attn.normalize',
#  'blocks.0.attn.normalize_1',
#  'blocks.0.attn.transpose_1',
#  'blocks.0.attn.matmul',
#  'blocks.0.attn.blocks_0_attn_temperature',
#  'blocks.0.attn.mul',
#  'blocks.0.attn.softmax',
#  'blocks.0.attn.attn_drop',
#  'blocks.0.attn.matmul_1',
#  'blocks.0.attn.permute_2',
#  'blocks.0.attn.reshape_2',
#  'blocks.0.attn.proj',
#  'blocks.0.attn.proj_drop',
#  'blocks.0.mul_1',
#  'blocks.0.drop_path',
#  'blocks.0.add_1',
#  'blocks.0.blocks_0_gamma3',
#  'blocks.0.norm3',
#  'blocks.0.local_mp.getattr_6',
#  'blocks.0.local_mp.getitem_10',
#  'blocks.0.local_mp.getitem_11',
#  'blocks.0.local_mp.getitem_12',
#  'blocks.0.local_mp.permute_3',
#  'blocks.0.local_mp.reshape_3',
#  'blocks.0.local_mp.conv1',
#  'blocks.0.local_mp.act',
#  'blocks.0.local_mp.bn',
#  'blocks.0.local_mp.conv2',
#  'blocks.0.local_mp.reshape_4',
#  'blocks.0.local_mp.permute_4',
#  'blocks.0.mul_2',
#  'blocks.0.drop_path_1',
#  'blocks.0.add_2',
#  'blocks.0.blocks_0_gamma2',
#  'blocks.0.norm2',
#  'blocks.0.mlp.fc1',
#  'blocks.0.mlp.act',
#  'blocks.0.mlp.drop',
#  'blocks.0.mlp.fc2',
#  'blocks.0.mlp.drop_1',
#  'blocks.0.mul_3',
#  'blocks.0.drop_path_2',
#  'blocks.0.add_3',
#  'blocks.1.blocks_1_gamma1',
#  'blocks.1.norm1',
#  'blocks.1.attn.getattr_7',
#  'blocks.1.attn.getitem_13',
#  'blocks.1.attn.getitem_14',
#  'blocks.1.attn.getitem_15',
#  'blocks.1.attn.qkv',
#  'blocks.1.attn.floordiv_1',
#  'blocks.1.attn.reshape_5',
#  'blocks.1.attn.permute_5',
#  'blocks.1.attn.getitem_16',
#  'blocks.1.attn.getitem_17',
#  'blocks.1.attn.getitem_18',
#  'blocks.1.attn.normalize_2',
#  'blocks.1.attn.normalize_3',
#  'blocks.1.attn.transpose_2',
#  'blocks.1.attn.matmul_2',
#  'blocks.1.attn.blocks_1_attn_temperature',
#  'blocks.1.attn.mul_4',
#  'blocks.1.attn.softmax_1',
#  'blocks.1.attn.attn_drop',
#  'blocks.1.attn.matmul_3',
#  'blocks.1.attn.permute_6',
#  'blocks.1.attn.reshape_6',
#  'blocks.1.attn.proj',
#  'blocks.1.attn.proj_drop',
#  'blocks.1.mul_5',
#  'blocks.1.drop_path',
#  'blocks.1.add_4',
#  'blocks.1.blocks_1_gamma3',
#  'blocks.1.norm3',
#  'blocks.1.local_mp.getattr_8',
#  'blocks.1.local_mp.getitem_19',
#  'blocks.1.local_mp.getitem_20',
#  'blocks.1.local_mp.getitem_21',
#  'blocks.1.local_mp.permute_7',
#  'blocks.1.local_mp.reshape_7',
#  'blocks.1.local_mp.conv1',
#  'blocks.1.local_mp.act',
#  'blocks.1.local_mp.bn',
#  'blocks.1.local_mp.conv2',
#  'blocks.1.local_mp.reshape_8',
#  'blocks.1.local_mp.permute_8',
#  'blocks.1.mul_6',
#  'blocks.1.drop_path_1',
#  'blocks.1.add_5',
#  'blocks.1.blocks_1_gamma2',
#  'blocks.1.norm2',
#  'blocks.1.mlp.fc1',
#  'blocks.1.mlp.act',
#  'blocks.1.mlp.drop',
#  'blocks.1.mlp.fc2',
#  'blocks.1.mlp.drop_1',
#  'blocks.1.mul_7',
#  'blocks.1.drop_path_2',
#  'blocks.1.add_6',
#  'blocks.2.blocks_2_gamma1',
#  'blocks.2.norm1',
#  'blocks.2.attn.getattr_9',
#  'blocks.2.attn.getitem_22',
#  'blocks.2.attn.getitem_23',
#  'blocks.2.attn.getitem_24',
#  'blocks.2.attn.qkv',
#  'blocks.2.attn.floordiv_2',
#  'blocks.2.attn.reshape_9',
#  'blocks.2.attn.permute_9',
#  'blocks.2.attn.getitem_25',
#  'blocks.2.attn.getitem_26',
#  'blocks.2.attn.getitem_27',
#  'blocks.2.attn.normalize_4',
#  'blocks.2.attn.normalize_5',
#  'blocks.2.attn.transpose_3',
#  'blocks.2.attn.matmul_4',
#  'blocks.2.attn.blocks_2_attn_temperature',
#  'blocks.2.attn.mul_8',
#  'blocks.2.attn.softmax_2',
#  'blocks.2.attn.attn_drop',
#  'blocks.2.attn.matmul_5',
#  'blocks.2.attn.permute_10',
#  'blocks.2.attn.reshape_10',
#  'blocks.2.attn.proj',
#  'blocks.2.attn.proj_drop',
#  'blocks.2.mul_9',
#  'blocks.2.drop_path',
#  'blocks.2.add_7',
#  'blocks.2.blocks_2_gamma3',
#  'blocks.2.norm3',
#  'blocks.2.local_mp.getattr_10',
#  'blocks.2.local_mp.getitem_28',
#  'blocks.2.local_mp.getitem_29',
#  'blocks.2.local_mp.getitem_30',
#  'blocks.2.local_mp.permute_11',
#  'blocks.2.local_mp.reshape_11',
#  'blocks.2.local_mp.conv1',
#  'blocks.2.local_mp.act',
#  'blocks.2.local_mp.bn',
#  'blocks.2.local_mp.conv2',
#  'blocks.2.local_mp.reshape_12',
#  'blocks.2.local_mp.permute_12',
#  'blocks.2.mul_10',
#  'blocks.2.drop_path_1',
#  'blocks.2.add_8',
#  'blocks.2.blocks_2_gamma2',
#  'blocks.2.norm2',
#  'blocks.2.mlp.fc1',
#  'blocks.2.mlp.act',
#  'blocks.2.mlp.drop',
#  'blocks.2.mlp.fc2',
#  'blocks.2.mlp.drop_1',
#  'blocks.2.mul_11',
#  'blocks.2.drop_path_2',
#  'blocks.2.add_9',
#  'blocks.3.blocks_3_gamma1',
#  'blocks.3.norm1',
#  'blocks.3.attn.getattr_11',
#  'blocks.3.attn.getitem_31',
#  'blocks.3.attn.getitem_32',
#  'blocks.3.attn.getitem_33',
#  'blocks.3.attn.qkv',
#  'blocks.3.attn.floordiv_3',
#  'blocks.3.attn.reshape_13',
#  'blocks.3.attn.permute_13',
#  'blocks.3.attn.getitem_34',
#  'blocks.3.attn.getitem_35',
#  'blocks.3.attn.getitem_36',
#  'blocks.3.attn.normalize_6',
#  'blocks.3.attn.normalize_7',
#  'blocks.3.attn.transpose_4',
#  'blocks.3.attn.matmul_6',
#  'blocks.3.attn.blocks_3_attn_temperature',
#  'blocks.3.attn.mul_12',
#  'blocks.3.attn.softmax_3',
#  'blocks.3.attn.attn_drop',
#  'blocks.3.attn.matmul_7',
#  'blocks.3.attn.permute_14',
#  'blocks.3.attn.reshape_14',
#  'blocks.3.attn.proj',
#  'blocks.3.attn.proj_drop',
#  'blocks.3.mul_13',
#  'blocks.3.drop_path',
#  'blocks.3.add_10',
#  'blocks.3.blocks_3_gamma3',
#  'blocks.3.norm3',
#  'blocks.3.local_mp.getattr_12',
#  'blocks.3.local_mp.getitem_37',
#  'blocks.3.local_mp.getitem_38',
#  'blocks.3.local_mp.getitem_39',
#  'blocks.3.local_mp.permute_15',
#  'blocks.3.local_mp.reshape_15',
#  'blocks.3.local_mp.conv1',
#  'blocks.3.local_mp.act',
#  'blocks.3.local_mp.bn',
#  'blocks.3.local_mp.conv2',
#  'blocks.3.local_mp.reshape_16',
#  'blocks.3.local_mp.permute_16',
#  'blocks.3.mul_14',
#  'blocks.3.drop_path_1',
#  'blocks.3.add_11',
#  'blocks.3.blocks_3_gamma2',
#  'blocks.3.norm2',
#  'blocks.3.mlp.fc1',
#  'blocks.3.mlp.act',
#  'blocks.3.mlp.drop',
#  'blocks.3.mlp.fc2',
#  'blocks.3.mlp.drop_1',
#  'blocks.3.mul_15',
#  'blocks.3.drop_path_2',
#  'blocks.3.add_12',
#  'blocks.4.blocks_4_gamma1',
#  'blocks.4.norm1',
#  'blocks.4.attn.getattr_13',
#  'blocks.4.attn.getitem_40',
#  'blocks.4.attn.getitem_41',
#  'blocks.4.attn.getitem_42',
#  'blocks.4.attn.qkv',
#  'blocks.4.attn.floordiv_4',
#  'blocks.4.attn.reshape_17',
#  'blocks.4.attn.permute_17',
#  'blocks.4.attn.getitem_43',
#  'blocks.4.attn.getitem_44',
#  'blocks.4.attn.getitem_45',
#  'blocks.4.attn.normalize_8',
#  'blocks.4.attn.normalize_9',
#  'blocks.4.attn.transpose_5',
#  'blocks.4.attn.matmul_8',
#  'blocks.4.attn.blocks_4_attn_temperature',
#  'blocks.4.attn.mul_16',
#  'blocks.4.attn.softmax_4',
#  'blocks.4.attn.attn_drop',
#  'blocks.4.attn.matmul_9',
#  'blocks.4.attn.permute_18',
#  'blocks.4.attn.reshape_18',
#  'blocks.4.attn.proj',
#  'blocks.4.attn.proj_drop',
#  'blocks.4.mul_17',
#  'blocks.4.drop_path',
#  'blocks.4.add_13',
#  'blocks.4.blocks_4_gamma3',
#  'blocks.4.norm3',
#  'blocks.4.local_mp.getattr_14',
#  'blocks.4.local_mp.getitem_46',
#  'blocks.4.local_mp.getitem_47',
#  'blocks.4.local_mp.getitem_48',
#  'blocks.4.local_mp.permute_19',
#  'blocks.4.local_mp.reshape_19',
#  'blocks.4.local_mp.conv1',
#  'blocks.4.local_mp.act',
#  'blocks.4.local_mp.bn',
#  'blocks.4.local_mp.conv2',
#  'blocks.4.local_mp.reshape_20',
#  'blocks.4.local_mp.permute_20',
#  'blocks.4.mul_18',
#  'blocks.4.drop_path_1',
#  'blocks.4.add_14',
#  'blocks.4.blocks_4_gamma2',
#  'blocks.4.norm2',
#  'blocks.4.mlp.fc1',
#  'blocks.4.mlp.act',
#  'blocks.4.mlp.drop',
#  'blocks.4.mlp.fc2',
#  'blocks.4.mlp.drop_1',
#  'blocks.4.mul_19',
#  'blocks.4.drop_path_2',
#  'blocks.4.add_15',
#  'blocks.5.blocks_5_gamma1',
#  'blocks.5.norm1',
#  'blocks.5.attn.getattr_15',
#  'blocks.5.attn.getitem_49',
#  'blocks.5.attn.getitem_50',
#  'blocks.5.attn.getitem_51',
#  'blocks.5.attn.qkv',
#  'blocks.5.attn.floordiv_5',
#  'blocks.5.attn.reshape_21',
#  'blocks.5.attn.permute_21',
#  'blocks.5.attn.getitem_52',
#  'blocks.5.attn.getitem_53',
#  'blocks.5.attn.getitem_54',
#  'blocks.5.attn.normalize_10',
#  'blocks.5.attn.normalize_11',
#  'blocks.5.attn.transpose_6',
#  'blocks.5.attn.matmul_10',
#  'blocks.5.attn.blocks_5_attn_temperature',
#  'blocks.5.attn.mul_20',
#  'blocks.5.attn.softmax_5',
#  'blocks.5.attn.attn_drop',
#  'blocks.5.attn.matmul_11',
#  'blocks.5.attn.permute_22',
#  'blocks.5.attn.reshape_22',
#  'blocks.5.attn.proj',
#  'blocks.5.attn.proj_drop',
#  'blocks.5.mul_21',
#  'blocks.5.drop_path',
#  'blocks.5.add_16',
#  'blocks.5.blocks_5_gamma3',
#  'blocks.5.norm3',
#  'blocks.5.local_mp.getattr_16',
#  'blocks.5.local_mp.getitem_55',
#  'blocks.5.local_mp.getitem_56',
#  'blocks.5.local_mp.getitem_57',
#  'blocks.5.local_mp.permute_23',
#  'blocks.5.local_mp.reshape_23',
#  'blocks.5.local_mp.conv1',
#  'blocks.5.local_mp.act',
#  'blocks.5.local_mp.bn',
#  'blocks.5.local_mp.conv2',
#  'blocks.5.local_mp.reshape_24',
#  'blocks.5.local_mp.permute_24',
#  'blocks.5.mul_22',
#  'blocks.5.drop_path_1',
#  'blocks.5.add_17',
#  'blocks.5.blocks_5_gamma2',
#  'blocks.5.norm2',
#  'blocks.5.mlp.fc1',
#  'blocks.5.mlp.act',
#  'blocks.5.mlp.drop',
#  'blocks.5.mlp.fc2',
#  'blocks.5.mlp.drop_1',
#  'blocks.5.mul_23',
#  'blocks.5.drop_path_2',
#  'blocks.5.add_18',
#  'blocks.6.blocks_6_gamma1',
#  'blocks.6.norm1',
#  'blocks.6.attn.getattr_17',
#  'blocks.6.attn.getitem_58',
#  'blocks.6.attn.getitem_59',
#  'blocks.6.attn.getitem_60',
#  'blocks.6.attn.qkv',
#  'blocks.6.attn.floordiv_6',
#  'blocks.6.attn.reshape_25',
#  'blocks.6.attn.permute_25',
#  'blocks.6.attn.getitem_61',
#  'blocks.6.attn.getitem_62',
#  'blocks.6.attn.getitem_63',
#  'blocks.6.attn.normalize_12',
#  'blocks.6.attn.normalize_13',
#  'blocks.6.attn.transpose_7',
#  'blocks.6.attn.matmul_12',
#  'blocks.6.attn.blocks_6_attn_temperature',
#  'blocks.6.attn.mul_24',
#  'blocks.6.attn.softmax_6',
#  'blocks.6.attn.attn_drop',
#  'blocks.6.attn.matmul_13',
#  'blocks.6.attn.permute_26',
#  'blocks.6.attn.reshape_26',
#  'blocks.6.attn.proj',
#  'blocks.6.attn.proj_drop',
#  'blocks.6.mul_25',
#  'blocks.6.drop_path',
#  'blocks.6.add_19',
#  'blocks.6.blocks_6_gamma3',
#  'blocks.6.norm3',
#  'blocks.6.local_mp.getattr_18',
#  'blocks.6.local_mp.getitem_64',
#  'blocks.6.local_mp.getitem_65',
#  'blocks.6.local_mp.getitem_66',
#  'blocks.6.local_mp.permute_27',
#  'blocks.6.local_mp.reshape_27',
#  'blocks.6.local_mp.conv1',
#  'blocks.6.local_mp.act',
#  'blocks.6.local_mp.bn',
#  'blocks.6.local_mp.conv2',
#  'blocks.6.local_mp.reshape_28',
#  'blocks.6.local_mp.permute_28',
#  'blocks.6.mul_26',
#  'blocks.6.drop_path_1',
#  'blocks.6.add_20',
#  'blocks.6.blocks_6_gamma2',
#  'blocks.6.norm2',
#  'blocks.6.mlp.fc1',
#  'blocks.6.mlp.act',
#  'blocks.6.mlp.drop',
#  'blocks.6.mlp.fc2',
#  'blocks.6.mlp.drop_1',
#  'blocks.6.mul_27',
#  'blocks.6.drop_path_2',
#  'blocks.6.add_21',
#  'blocks.7.blocks_7_gamma1',
#  'blocks.7.norm1',
#  'blocks.7.attn.getattr_19',
#  'blocks.7.attn.getitem_67',
#  'blocks.7.attn.getitem_68',
#  'blocks.7.attn.getitem_69',
#  'blocks.7.attn.qkv',
#  'blocks.7.attn.floordiv_7',
#  'blocks.7.attn.reshape_29',
#  'blocks.7.attn.permute_29',
#  'blocks.7.attn.getitem_70',
#  'blocks.7.attn.getitem_71',
#  'blocks.7.attn.getitem_72',
#  'blocks.7.attn.normalize_14',
#  'blocks.7.attn.normalize_15',
#  'blocks.7.attn.transpose_8',
#  'blocks.7.attn.matmul_14',
#  'blocks.7.attn.blocks_7_attn_temperature',
#  'blocks.7.attn.mul_28',
#  'blocks.7.attn.softmax_7',
#  'blocks.7.attn.attn_drop',
#  'blocks.7.attn.matmul_15',
#  'blocks.7.attn.permute_30',
#  'blocks.7.attn.reshape_30',
#  'blocks.7.attn.proj',
#  'blocks.7.attn.proj_drop',
#  'blocks.7.mul_29',
#  'blocks.7.drop_path',
#  'blocks.7.add_22',
#  'blocks.7.blocks_7_gamma3',
#  'blocks.7.norm3',
#  'blocks.7.local_mp.getattr_20',
#  'blocks.7.local_mp.getitem_73',
#  'blocks.7.local_mp.getitem_74',
#  'blocks.7.local_mp.getitem_75',
#  'blocks.7.local_mp.permute_31',
#  'blocks.7.local_mp.reshape_31',
#  'blocks.7.local_mp.conv1',
#  'blocks.7.local_mp.act',
#  'blocks.7.local_mp.bn',
#  'blocks.7.local_mp.conv2',
#  'blocks.7.local_mp.reshape_32',
#  'blocks.7.local_mp.permute_32',
#  'blocks.7.mul_30',
#  'blocks.7.drop_path_1',
#  'blocks.7.add_23',
#  'blocks.7.blocks_7_gamma2',
#  'blocks.7.norm2',
#  'blocks.7.mlp.fc1',
#  'blocks.7.mlp.act',
#  'blocks.7.mlp.drop',
#  'blocks.7.mlp.fc2',
#  'blocks.7.mlp.drop_1',
#  'blocks.7.mul_31',
#  'blocks.7.drop_path_2',
#  'blocks.7.add_24',
#  'blocks.8.blocks_8_gamma1',
#  'blocks.8.norm1',
#  'blocks.8.attn.getattr_21',
#  'blocks.8.attn.getitem_76',
#  'blocks.8.attn.getitem_77',
#  'blocks.8.attn.getitem_78',
#  'blocks.8.attn.qkv',
#  'blocks.8.attn.floordiv_8',
#  'blocks.8.attn.reshape_33',
#  'blocks.8.attn.permute_33',
#  'blocks.8.attn.getitem_79',
#  'blocks.8.attn.getitem_80',
#  'blocks.8.attn.getitem_81',
#  'blocks.8.attn.normalize_16',
#  'blocks.8.attn.normalize_17',
#  'blocks.8.attn.transpose_9',
#  'blocks.8.attn.matmul_16',
#  'blocks.8.attn.blocks_8_attn_temperature',
#  'blocks.8.attn.mul_32',
#  'blocks.8.attn.softmax_8',
#  'blocks.8.attn.attn_drop',
#  'blocks.8.attn.matmul_17',
#  'blocks.8.attn.permute_34',
#  'blocks.8.attn.reshape_34',
#  'blocks.8.attn.proj',
#  'blocks.8.attn.proj_drop',
#  'blocks.8.mul_33',
#  'blocks.8.drop_path',
#  'blocks.8.add_25',
#  'blocks.8.blocks_8_gamma3',
#  'blocks.8.norm3',
#  'blocks.8.local_mp.getattr_22',
#  'blocks.8.local_mp.getitem_82',
#  'blocks.8.local_mp.getitem_83',
#  'blocks.8.local_mp.getitem_84',
#  'blocks.8.local_mp.permute_35',
#  'blocks.8.local_mp.reshape_35',
#  'blocks.8.local_mp.conv1',
#  'blocks.8.local_mp.act',
#  'blocks.8.local_mp.bn',
#  'blocks.8.local_mp.conv2',
#  'blocks.8.local_mp.reshape_36',
#  'blocks.8.local_mp.permute_36',
#  'blocks.8.mul_34',
#  'blocks.8.drop_path_1',
#  'blocks.8.add_26',
#  'blocks.8.blocks_8_gamma2',
#  'blocks.8.norm2',
#  'blocks.8.mlp.fc1',
#  'blocks.8.mlp.act',
#  'blocks.8.mlp.drop',
#  'blocks.8.mlp.fc2',
#  'blocks.8.mlp.drop_1',
#  'blocks.8.mul_35',
#  'blocks.8.drop_path_2',
#  'blocks.8.add_27',
#  'blocks.9.blocks_9_gamma1',
#  'blocks.9.norm1',
#  'blocks.9.attn.getattr_23',
#  'blocks.9.attn.getitem_85',
#  'blocks.9.attn.getitem_86',
#  'blocks.9.attn.getitem_87',
#  'blocks.9.attn.qkv',
#  'blocks.9.attn.floordiv_9',
#  'blocks.9.attn.reshape_37',
#  'blocks.9.attn.permute_37',
#  'blocks.9.attn.getitem_88',
#  'blocks.9.attn.getitem_89',
#  'blocks.9.attn.getitem_90',
#  'blocks.9.attn.normalize_18',
#  'blocks.9.attn.normalize_19',
#  'blocks.9.attn.transpose_10',
#  'blocks.9.attn.matmul_18',
#  'blocks.9.attn.blocks_9_attn_temperature',
#  'blocks.9.attn.mul_36',
#  'blocks.9.attn.softmax_9',
#  'blocks.9.attn.attn_drop',
#  'blocks.9.attn.matmul_19',
#  'blocks.9.attn.permute_38',
#  'blocks.9.attn.reshape_38',
#  'blocks.9.attn.proj',
#  'blocks.9.attn.proj_drop',
#  'blocks.9.mul_37',
#  'blocks.9.drop_path',
#  'blocks.9.add_28',
#  'blocks.9.blocks_9_gamma3',
#  'blocks.9.norm3',
#  'blocks.9.local_mp.getattr_24',
#  'blocks.9.local_mp.getitem_91',
#  'blocks.9.local_mp.getitem_92',
#  'blocks.9.local_mp.getitem_93',
#  'blocks.9.local_mp.permute_39',
#  'blocks.9.local_mp.reshape_39',
#  'blocks.9.local_mp.conv1',
#  'blocks.9.local_mp.act',
#  'blocks.9.local_mp.bn',
#  'blocks.9.local_mp.conv2',
#  'blocks.9.local_mp.reshape_40',
#  'blocks.9.local_mp.permute_40',
#  'blocks.9.mul_38',
#  'blocks.9.drop_path_1',
#  'blocks.9.add_29',
#  'blocks.9.blocks_9_gamma2',
#  'blocks.9.norm2',
#  'blocks.9.mlp.fc1',
#  'blocks.9.mlp.act',
#  'blocks.9.mlp.drop',
#  'blocks.9.mlp.fc2',
#  'blocks.9.mlp.drop_1',
#  'blocks.9.mul_39',
#  'blocks.9.drop_path_2',
#  'blocks.9.add_30',
#  'blocks.10.blocks_10_gamma1',
#  'blocks.10.norm1',
#  'blocks.10.attn.getattr_25',
#  'blocks.10.attn.getitem_94',
#  'blocks.10.attn.getitem_95',
#  'blocks.10.attn.getitem_96',
#  'blocks.10.attn.qkv',
#  'blocks.10.attn.floordiv_10',
#  'blocks.10.attn.reshape_41',
#  'blocks.10.attn.permute_41',
#  'blocks.10.attn.getitem_97',
#  'blocks.10.attn.getitem_98',
#  'blocks.10.attn.getitem_99',
#  'blocks.10.attn.normalize_20',
#  'blocks.10.attn.normalize_21',
#  'blocks.10.attn.transpose_11',
#  'blocks.10.attn.matmul_20',
#  'blocks.10.attn.blocks_10_attn_temperature',
#  'blocks.10.attn.mul_40',
#  'blocks.10.attn.softmax_10',
#  'blocks.10.attn.attn_drop',
#  'blocks.10.attn.matmul_21',
#  'blocks.10.attn.permute_42',
#  'blocks.10.attn.reshape_42',
#  'blocks.10.attn.proj',
#  'blocks.10.attn.proj_drop',
#  'blocks.10.mul_41',
#  'blocks.10.drop_path',
#  'blocks.10.add_31',
#  'blocks.10.blocks_10_gamma3',
#  'blocks.10.norm3',
#  'blocks.10.local_mp.getattr_26',
#  'blocks.10.local_mp.getitem_100',
#  'blocks.10.local_mp.getitem_101',
#  'blocks.10.local_mp.getitem_102',
#  'blocks.10.local_mp.permute_43',
#  'blocks.10.local_mp.reshape_43',
#  'blocks.10.local_mp.conv1',
#  'blocks.10.local_mp.act',
#  'blocks.10.local_mp.bn',
#  'blocks.10.local_mp.conv2',
#  'blocks.10.local_mp.reshape_44',
#  'blocks.10.local_mp.permute_44',
#  'blocks.10.mul_42',
#  'blocks.10.drop_path_1',
#  'blocks.10.add_32',
#  'blocks.10.blocks_10_gamma2',
#  'blocks.10.norm2',
#  'blocks.10.mlp.fc1',
#  'blocks.10.mlp.act',
#  'blocks.10.mlp.drop',
#  'blocks.10.mlp.fc2',
#  'blocks.10.mlp.drop_1',
#  'blocks.10.mul_43',
#  'blocks.10.drop_path_2',
#  'blocks.10.add_33',
#  'blocks.11.blocks_11_gamma1',
#  'blocks.11.norm1',
#  'blocks.11.attn.getattr_27',
#  'blocks.11.attn.getitem_103',
#  'blocks.11.attn.getitem_104',
#  'blocks.11.attn.getitem_105',
#  'blocks.11.attn.qkv',
#  'blocks.11.attn.floordiv_11',
#  'blocks.11.attn.reshape_45',
#  'blocks.11.attn.permute_45',
#  'blocks.11.attn.getitem_106',
#  'blocks.11.attn.getitem_107',
#  'blocks.11.attn.getitem_108',
#  'blocks.11.attn.normalize_22',
#  'blocks.11.attn.normalize_23',
#  'blocks.11.attn.transpose_12',
#  'blocks.11.attn.matmul_22',
#  'blocks.11.attn.blocks_11_attn_temperature',
#  'blocks.11.attn.mul_44',
#  'blocks.11.attn.softmax_11',
#  'blocks.11.attn.attn_drop',
#  'blocks.11.attn.matmul_23',
#  'blocks.11.attn.permute_46',
#  'blocks.11.attn.reshape_46',
#  'blocks.11.attn.proj',
#  'blocks.11.attn.proj_drop',
#  'blocks.11.mul_45',
#  'blocks.11.drop_path',
#  'blocks.11.add_34',
#  'blocks.11.blocks_11_gamma3',
#  'blocks.11.norm3',
#  'blocks.11.local_mp.getattr_28',
#  'blocks.11.local_mp.getitem_109',
#  'blocks.11.local_mp.getitem_110',
#  'blocks.11.local_mp.getitem_111',
#  'blocks.11.local_mp.permute_47',
#  'blocks.11.local_mp.reshape_47',
#  'blocks.11.local_mp.conv1',
#  'blocks.11.local_mp.act',
#  'blocks.11.local_mp.bn',
#  'blocks.11.local_mp.conv2',
#  'blocks.11.local_mp.reshape_48',
#  'blocks.11.local_mp.permute_48',
#  'blocks.11.mul_46',
#  'blocks.11.drop_path_1',
#  'blocks.11.add_35',
#  'blocks.11.blocks_11_gamma2',
#  'blocks.11.norm2',
#  'blocks.11.mlp.fc1',
#  'blocks.11.mlp.act',
#  'blocks.11.mlp.drop',
#  'blocks.11.mlp.fc2',
#  'blocks.11.mlp.drop_1',
#  'blocks.11.mul_47',
#  'blocks.11.drop_path_2',
#  'blocks.11.add_36',
#  'blocks.12.blocks_12_gamma1',
#  'blocks.12.norm1',
#  'blocks.12.attn.getattr_29',
#  'blocks.12.attn.getitem_112',
#  'blocks.12.attn.getitem_113',
#  'blocks.12.attn.getitem_114',
#  'blocks.12.attn.qkv',
#  'blocks.12.attn.floordiv_12',
#  'blocks.12.attn.reshape_49',
#  'blocks.12.attn.permute_49',
#  'blocks.12.attn.getitem_115',
#  'blocks.12.attn.getitem_116',
#  'blocks.12.attn.getitem_117',
#  'blocks.12.attn.normalize_24',
#  'blocks.12.attn.normalize_25',
#  'blocks.12.attn.transpose_13',
#  'blocks.12.attn.matmul_24',
#  'blocks.12.attn.blocks_12_attn_temperature',
#  'blocks.12.attn.mul_48',
#  'blocks.12.attn.softmax_12',
#  'blocks.12.attn.attn_drop',
#  'blocks.12.attn.matmul_25',
#  'blocks.12.attn.permute_50',
#  'blocks.12.attn.reshape_50',
#  'blocks.12.attn.proj',
#  'blocks.12.attn.proj_drop',
#  'blocks.12.mul_49',
#  'blocks.12.drop_path',
#  'blocks.12.add_37',
#  'blocks.12.blocks_12_gamma3',
#  'blocks.12.norm3',
#  'blocks.12.local_mp.getattr_30',
#  'blocks.12.local_mp.getitem_118',
#  'blocks.12.local_mp.getitem_119',
#  'blocks.12.local_mp.getitem_120',
#  'blocks.12.local_mp.permute_51',
#  'blocks.12.local_mp.reshape_51',
#  'blocks.12.local_mp.conv1',
#  'blocks.12.local_mp.act',
#  'blocks.12.local_mp.bn',
#  'blocks.12.local_mp.conv2',
#  'blocks.12.local_mp.reshape_52',
#  'blocks.12.local_mp.permute_52',
#  'blocks.12.mul_50',
#  'blocks.12.drop_path_1',
#  'blocks.12.add_38',
#  'blocks.12.blocks_12_gamma2',
#  'blocks.12.norm2',
#  'blocks.12.mlp.fc1',
#  'blocks.12.mlp.act',
#  'blocks.12.mlp.drop',
#  'blocks.12.mlp.fc2',
#  'blocks.12.mlp.drop_1',
#  'blocks.12.mul_51',
#  'blocks.12.drop_path_2',
#  'blocks.12.add_39',
#  'blocks.13.blocks_13_gamma1',
#  'blocks.13.norm1',
#  'blocks.13.attn.getattr_31',
#  'blocks.13.attn.getitem_121',
#  'blocks.13.attn.getitem_122',
#  'blocks.13.attn.getitem_123',
#  'blocks.13.attn.qkv',
#  'blocks.13.attn.floordiv_13',
#  'blocks.13.attn.reshape_53',
#  'blocks.13.attn.permute_53',
#  'blocks.13.attn.getitem_124',
#  'blocks.13.attn.getitem_125',
#  'blocks.13.attn.getitem_126',
#  'blocks.13.attn.normalize_26',
#  'blocks.13.attn.normalize_27',
#  'blocks.13.attn.transpose_14',
#  'blocks.13.attn.matmul_26',
#  'blocks.13.attn.blocks_13_attn_temperature',
#  'blocks.13.attn.mul_52',
#  'blocks.13.attn.softmax_13',
#  'blocks.13.attn.attn_drop',
#  'blocks.13.attn.matmul_27',
#  'blocks.13.attn.permute_54',
#  'blocks.13.attn.reshape_54',
#  'blocks.13.attn.proj',
#  'blocks.13.attn.proj_drop',
#  'blocks.13.mul_53',
#  'blocks.13.drop_path',
#  'blocks.13.add_40',
#  'blocks.13.blocks_13_gamma3',
#  'blocks.13.norm3',
#  'blocks.13.local_mp.getattr_32',
#  'blocks.13.local_mp.getitem_127',
#  'blocks.13.local_mp.getitem_128',
#  'blocks.13.local_mp.getitem_129',
#  'blocks.13.local_mp.permute_55',
#  'blocks.13.local_mp.reshape_55',
#  'blocks.13.local_mp.conv1',
#  'blocks.13.local_mp.act',
#  'blocks.13.local_mp.bn',
#  'blocks.13.local_mp.conv2',
#  'blocks.13.local_mp.reshape_56',
#  'blocks.13.local_mp.permute_56',
#  'blocks.13.mul_54',
#  'blocks.13.drop_path_1',
#  'blocks.13.add_41',
#  'blocks.13.blocks_13_gamma2',
#  'blocks.13.norm2',
#  'blocks.13.mlp.fc1',
#  'blocks.13.mlp.act',
#  'blocks.13.mlp.drop',
#  'blocks.13.mlp.fc2',
#  'blocks.13.mlp.drop_1',
#  'blocks.13.mul_55',
#  'blocks.13.drop_path_2',
#  'blocks.13.add_42',
#  'blocks.14.blocks_14_gamma1',
#  'blocks.14.norm1',
#  'blocks.14.attn.getattr_33',
#  'blocks.14.attn.getitem_130',
#  'blocks.14.attn.getitem_131',
#  'blocks.14.attn.getitem_132',
#  'blocks.14.attn.qkv',
#  'blocks.14.attn.floordiv_14',
#  'blocks.14.attn.reshape_57',
#  'blocks.14.attn.permute_57',
#  'blocks.14.attn.getitem_133',
#  'blocks.14.attn.getitem_134',
#  'blocks.14.attn.getitem_135',
#  'blocks.14.attn.normalize_28',
#  'blocks.14.attn.normalize_29',
#  'blocks.14.attn.transpose_15',
#  'blocks.14.attn.matmul_28',
#  'blocks.14.attn.blocks_14_attn_temperature',
#  'blocks.14.attn.mul_56',
#  'blocks.14.attn.softmax_14',
#  'blocks.14.attn.attn_drop',
#  'blocks.14.attn.matmul_29',
#  'blocks.14.attn.permute_58',
#  'blocks.14.attn.reshape_58',
#  'blocks.14.attn.proj',
#  'blocks.14.attn.proj_drop',
#  'blocks.14.mul_57',
#  'blocks.14.drop_path',
#  'blocks.14.add_43',
#  'blocks.14.blocks_14_gamma3',
#  'blocks.14.norm3',
#  'blocks.14.local_mp.getattr_34',
#  'blocks.14.local_mp.getitem_136',
#  'blocks.14.local_mp.getitem_137',
#  'blocks.14.local_mp.getitem_138',
#  'blocks.14.local_mp.permute_59',
#  'blocks.14.local_mp.reshape_59',
#  'blocks.14.local_mp.conv1',
#  'blocks.14.local_mp.act',
#  'blocks.14.local_mp.bn',
#  'blocks.14.local_mp.conv2',
#  'blocks.14.local_mp.reshape_60',
#  'blocks.14.local_mp.permute_60',
#  'blocks.14.mul_58',
#  'blocks.14.drop_path_1',
#  'blocks.14.add_44',
#  'blocks.14.blocks_14_gamma2',
#  'blocks.14.norm2',
#  'blocks.14.mlp.fc1',
#  'blocks.14.mlp.act',
#  'blocks.14.mlp.drop',
#  'blocks.14.mlp.fc2',
#  'blocks.14.mlp.drop_1',
#  'blocks.14.mul_59',
#  'blocks.14.drop_path_2',
#  'blocks.14.add_45',
#  'blocks.15.blocks_15_gamma1',
#  'blocks.15.norm1',
#  'blocks.15.attn.getattr_35',
#  'blocks.15.attn.getitem_139',
#  'blocks.15.attn.getitem_140',
#  'blocks.15.attn.getitem_141',
#  'blocks.15.attn.qkv',
#  'blocks.15.attn.floordiv_15',
#  'blocks.15.attn.reshape_61',
#  'blocks.15.attn.permute_61',
#  'blocks.15.attn.getitem_142',
#  'blocks.15.attn.getitem_143',
#  'blocks.15.attn.getitem_144',
#  'blocks.15.attn.normalize_30',
#  'blocks.15.attn.normalize_31',
#  'blocks.15.attn.transpose_16',
#  'blocks.15.attn.matmul_30',
#  'blocks.15.attn.blocks_15_attn_temperature',
#  'blocks.15.attn.mul_60',
#  'blocks.15.attn.softmax_15',
#  'blocks.15.attn.attn_drop',
#  'blocks.15.attn.matmul_31',
#  'blocks.15.attn.permute_62',
#  'blocks.15.attn.reshape_62',
#  'blocks.15.attn.proj',
#  'blocks.15.attn.proj_drop',
#  'blocks.15.mul_61',
#  'blocks.15.drop_path',
#  'blocks.15.add_46',
#  'blocks.15.blocks_15_gamma3',
#  'blocks.15.norm3',
#  'blocks.15.local_mp.getattr_36',
#  'blocks.15.local_mp.getitem_145',
#  'blocks.15.local_mp.getitem_146',
#  'blocks.15.local_mp.getitem_147',
#  'blocks.15.local_mp.permute_63',
#  'blocks.15.local_mp.reshape_63',
#  'blocks.15.local_mp.conv1',
#  'blocks.15.local_mp.act',
#  'blocks.15.local_mp.bn',
#  'blocks.15.local_mp.conv2',
#  'blocks.15.local_mp.reshape_64',
#  'blocks.15.local_mp.permute_64',
#  'blocks.15.mul_62',
#  'blocks.15.drop_path_1',
#  'blocks.15.add_47',
#  'blocks.15.blocks_15_gamma2',
#  'blocks.15.norm2',
#  'blocks.15.mlp.fc1',
#  'blocks.15.mlp.act',
#  'blocks.15.mlp.drop',
#  'blocks.15.mlp.fc2',
#  'blocks.15.mlp.drop_1',
#  'blocks.15.mul_63',
#  'blocks.15.drop_path_2',
#  'blocks.15.add_48',
#  'blocks.16.blocks_16_gamma1',
#  'blocks.16.norm1',
#  'blocks.16.attn.getattr_37',
#  'blocks.16.attn.getitem_148',
#  'blocks.16.attn.getitem_149',
#  'blocks.16.attn.getitem_150',
#  'blocks.16.attn.qkv',
#  'blocks.16.attn.floordiv_16',
#  'blocks.16.attn.reshape_65',
#  'blocks.16.attn.permute_65',
#  'blocks.16.attn.getitem_151',
#  'blocks.16.attn.getitem_152',
#  'blocks.16.attn.getitem_153',
#  'blocks.16.attn.normalize_32',
#  'blocks.16.attn.normalize_33',
#  'blocks.16.attn.transpose_17',
#  'blocks.16.attn.matmul_32',
#  'blocks.16.attn.blocks_16_attn_temperature',
#  'blocks.16.attn.mul_64',
#  'blocks.16.attn.softmax_16',
#  'blocks.16.attn.attn_drop',
#  'blocks.16.attn.matmul_33',
#  'blocks.16.attn.permute_66',
#  'blocks.16.attn.reshape_66',
#  'blocks.16.attn.proj',
#  'blocks.16.attn.proj_drop',
#  'blocks.16.mul_65',
#  'blocks.16.drop_path',
#  'blocks.16.add_49',
#  'blocks.16.blocks_16_gamma3',
#  'blocks.16.norm3',
#  'blocks.16.local_mp.getattr_38',
#  'blocks.16.local_mp.getitem_154',
#  'blocks.16.local_mp.getitem_155',
#  'blocks.16.local_mp.getitem_156',
#  'blocks.16.local_mp.permute_67',
#  'blocks.16.local_mp.reshape_67',
#  'blocks.16.local_mp.conv1',
#  'blocks.16.local_mp.act',
#  'blocks.16.local_mp.bn',
#  'blocks.16.local_mp.conv2',
#  'blocks.16.local_mp.reshape_68',
#  'blocks.16.local_mp.permute_68',
#  'blocks.16.mul_66',
#  'blocks.16.drop_path_1',
#  'blocks.16.add_50',
#  'blocks.16.blocks_16_gamma2',
#  'blocks.16.norm2',
#  'blocks.16.mlp.fc1',
#  'blocks.16.mlp.act',
#  'blocks.16.mlp.drop',
#  'blocks.16.mlp.fc2',
#  'blocks.16.mlp.drop_1',
#  'blocks.16.mul_67',
#  'blocks.16.drop_path_2',
#  'blocks.16.add_51',
#  'blocks.17.blocks_17_gamma1',
#  'blocks.17.norm1',
#  'blocks.17.attn.getattr_39',
#  'blocks.17.attn.getitem_157',
#  'blocks.17.attn.getitem_158',
#  'blocks.17.attn.getitem_159',
#  'blocks.17.attn.qkv',
#  'blocks.17.attn.floordiv_17',
#  'blocks.17.attn.reshape_69',
#  'blocks.17.attn.permute_69',
#  'blocks.17.attn.getitem_160',
#  'blocks.17.attn.getitem_161',
#  'blocks.17.attn.getitem_162',
#  'blocks.17.attn.normalize_34',
#  'blocks.17.attn.normalize_35',
#  'blocks.17.attn.transpose_18',
#  'blocks.17.attn.matmul_34',
#  'blocks.17.attn.blocks_17_attn_temperature',
#  'blocks.17.attn.mul_68',
#  'blocks.17.attn.softmax_17',
#  'blocks.17.attn.attn_drop',
#  'blocks.17.attn.matmul_35',
#  'blocks.17.attn.permute_70',
#  'blocks.17.attn.reshape_70',
#  'blocks.17.attn.proj',
#  'blocks.17.attn.proj_drop',
#  'blocks.17.mul_69',
#  'blocks.17.drop_path',
#  'blocks.17.add_52',
#  'blocks.17.blocks_17_gamma3',
#  'blocks.17.norm3',
#  'blocks.17.local_mp.getattr_40',
#  'blocks.17.local_mp.getitem_163',
#  'blocks.17.local_mp.getitem_164',
#  'blocks.17.local_mp.getitem_165',
#  'blocks.17.local_mp.permute_71',
#  'blocks.17.local_mp.reshape_71',
#  'blocks.17.local_mp.conv1',
#  'blocks.17.local_mp.act',
#  'blocks.17.local_mp.bn',
#  'blocks.17.local_mp.conv2',
#  'blocks.17.local_mp.reshape_72',
#  'blocks.17.local_mp.permute_72',
#  'blocks.17.mul_70',
#  'blocks.17.drop_path_1',
#  'blocks.17.add_53',
#  'blocks.17.blocks_17_gamma2',
#  'blocks.17.norm2',
#  'blocks.17.mlp.fc1',
#  'blocks.17.mlp.act',
#  'blocks.17.mlp.drop',
#  'blocks.17.mlp.fc2',
#  'blocks.17.mlp.drop_1',
#  'blocks.17.mul_71',
#  'blocks.17.drop_path_2',
#  'blocks.17.add_54',
#  'blocks.18.blocks_18_gamma1',
#  'blocks.18.norm1',
#  'blocks.18.attn.getattr_41',
#  'blocks.18.attn.getitem_166',
#  'blocks.18.attn.getitem_167',
#  'blocks.18.attn.getitem_168',
#  'blocks.18.attn.qkv',
#  'blocks.18.attn.floordiv_18',
#  'blocks.18.attn.reshape_73',
#  'blocks.18.attn.permute_73',
#  'blocks.18.attn.getitem_169',
#  'blocks.18.attn.getitem_170',
#  'blocks.18.attn.getitem_171',
#  'blocks.18.attn.normalize_36',
#  'blocks.18.attn.normalize_37',
#  'blocks.18.attn.transpose_19',
#  'blocks.18.attn.matmul_36',
#  'blocks.18.attn.blocks_18_attn_temperature',
#  'blocks.18.attn.mul_72',
#  'blocks.18.attn.softmax_18',
#  'blocks.18.attn.attn_drop',
#  'blocks.18.attn.matmul_37',
#  'blocks.18.attn.permute_74',
#  'blocks.18.attn.reshape_74',
#  'blocks.18.attn.proj',
#  'blocks.18.attn.proj_drop',
#  'blocks.18.mul_73',
#  'blocks.18.drop_path',
#  'blocks.18.add_55',
#  'blocks.18.blocks_18_gamma3',
#  'blocks.18.norm3',
#  'blocks.18.local_mp.getattr_42',
#  'blocks.18.local_mp.getitem_172',
#  'blocks.18.local_mp.getitem_173',
#  'blocks.18.local_mp.getitem_174',
#  'blocks.18.local_mp.permute_75',
#  'blocks.18.local_mp.reshape_75',
#  'blocks.18.local_mp.conv1',
#  'blocks.18.local_mp.act',
#  'blocks.18.local_mp.bn',
#  'blocks.18.local_mp.conv2',
#  'blocks.18.local_mp.reshape_76',
#  'blocks.18.local_mp.permute_76',
#  'blocks.18.mul_74',
#  'blocks.18.drop_path_1',
#  'blocks.18.add_56',
#  'blocks.18.blocks_18_gamma2',
#  'blocks.18.norm2',
#  'blocks.18.mlp.fc1',
#  'blocks.18.mlp.act',
#  'blocks.18.mlp.drop',
#  'blocks.18.mlp.fc2',
#  'blocks.18.mlp.drop_1',
#  'blocks.18.mul_75',
#  'blocks.18.drop_path_2',
#  'blocks.18.add_57',
#  'blocks.19.blocks_19_gamma1',
#  'blocks.19.norm1',
#  'blocks.19.attn.getattr_43',
#  'blocks.19.attn.getitem_175',
#  'blocks.19.attn.getitem_176',
#  'blocks.19.attn.getitem_177',
#  'blocks.19.attn.qkv',
#  'blocks.19.attn.floordiv_19',
#  'blocks.19.attn.reshape_77',
#  'blocks.19.attn.permute_77',
#  'blocks.19.attn.getitem_178',
#  'blocks.19.attn.getitem_179',
#  'blocks.19.attn.getitem_180',
#  'blocks.19.attn.normalize_38',
#  'blocks.19.attn.normalize_39',
#  'blocks.19.attn.transpose_20',
#  'blocks.19.attn.matmul_38',
#  'blocks.19.attn.blocks_19_attn_temperature',
#  'blocks.19.attn.mul_76',
#  'blocks.19.attn.softmax_19',
#  'blocks.19.attn.attn_drop',
#  'blocks.19.attn.matmul_39',
#  'blocks.19.attn.permute_78',
#  'blocks.19.attn.reshape_78',
#  'blocks.19.attn.proj',
#  'blocks.19.attn.proj_drop',
#  'blocks.19.mul_77',
#  'blocks.19.drop_path',
#  'blocks.19.add_58',
#  'blocks.19.blocks_19_gamma3',
#  'blocks.19.norm3',
#  'blocks.19.local_mp.getattr_44',
#  'blocks.19.local_mp.getitem_181',
#  'blocks.19.local_mp.getitem_182',
#  'blocks.19.local_mp.getitem_183',
#  'blocks.19.local_mp.permute_79',
#  'blocks.19.local_mp.reshape_79',
#  'blocks.19.local_mp.conv1',
#  'blocks.19.local_mp.act',
#  'blocks.19.local_mp.bn',
#  'blocks.19.local_mp.conv2',
#  'blocks.19.local_mp.reshape_80',
#  'blocks.19.local_mp.permute_80',
#  'blocks.19.mul_78',
#  'blocks.19.drop_path_1',
#  'blocks.19.add_59',
#  'blocks.19.blocks_19_gamma2',
#  'blocks.19.norm2',
#  'blocks.19.mlp.fc1',
#  'blocks.19.mlp.act',
#  'blocks.19.mlp.drop',
#  'blocks.19.mlp.fc2',
#  'blocks.19.mlp.drop_1',
#  'blocks.19.mul_79',
#  'blocks.19.drop_path_2',
#  'blocks.19.add_60',
#  'blocks.20.blocks_20_gamma1',
#  'blocks.20.norm1',
#  'blocks.20.attn.getattr_45',
#  'blocks.20.attn.getitem_184',
#  'blocks.20.attn.getitem_185',
#  'blocks.20.attn.getitem_186',
#  'blocks.20.attn.qkv',
#  'blocks.20.attn.floordiv_20',
#  'blocks.20.attn.reshape_81',
#  'blocks.20.attn.permute_81',
#  'blocks.20.attn.getitem_187',
#  'blocks.20.attn.getitem_188',
#  'blocks.20.attn.getitem_189',
#  'blocks.20.attn.normalize_40',
#  'blocks.20.attn.normalize_41',
#  'blocks.20.attn.transpose_21',
#  'blocks.20.attn.matmul_40',
#  'blocks.20.attn.blocks_20_attn_temperature',
#  'blocks.20.attn.mul_80',
#  'blocks.20.attn.softmax_20',
#  'blocks.20.attn.attn_drop',
#  'blocks.20.attn.matmul_41',
#  'blocks.20.attn.permute_82',
#  'blocks.20.attn.reshape_82',
#  'blocks.20.attn.proj',
#  'blocks.20.attn.proj_drop',
#  'blocks.20.mul_81',
#  'blocks.20.drop_path',
#  'blocks.20.add_61',
#  'blocks.20.blocks_20_gamma3',
#  'blocks.20.norm3',
#  'blocks.20.local_mp.getattr_46',
#  'blocks.20.local_mp.getitem_190',
#  'blocks.20.local_mp.getitem_191',
#  'blocks.20.local_mp.getitem_192',
#  'blocks.20.local_mp.permute_83',
#  'blocks.20.local_mp.reshape_83',
#  'blocks.20.local_mp.conv1',
#  'blocks.20.local_mp.act',
#  'blocks.20.local_mp.bn',
#  'blocks.20.local_mp.conv2',
#  'blocks.20.local_mp.reshape_84',
#  'blocks.20.local_mp.permute_84',
#  'blocks.20.mul_82',
#  'blocks.20.drop_path_1',
#  'blocks.20.add_62',
#  'blocks.20.blocks_20_gamma2',
#  'blocks.20.norm2',
#  'blocks.20.mlp.fc1',
#  'blocks.20.mlp.act',
#  'blocks.20.mlp.drop',
#  'blocks.20.mlp.fc2',
#  'blocks.20.mlp.drop_1',
#  'blocks.20.mul_83',
#  'blocks.20.drop_path_2',
#  'blocks.20.add_63',
#  'blocks.21.blocks_21_gamma1',
#  'blocks.21.norm1',
#  'blocks.21.attn.getattr_47',
#  'blocks.21.attn.getitem_193',
#  'blocks.21.attn.getitem_194',
#  'blocks.21.attn.getitem_195',
#  'blocks.21.attn.qkv',
#  'blocks.21.attn.floordiv_21',
#  'blocks.21.attn.reshape_85',
#  'blocks.21.attn.permute_85',
#  'blocks.21.attn.getitem_196',
#  'blocks.21.attn.getitem_197',
#  'blocks.21.attn.getitem_198',
#  'blocks.21.attn.normalize_42',
#  'blocks.21.attn.normalize_43',
#  'blocks.21.attn.transpose_22',
#  'blocks.21.attn.matmul_42',
#  'blocks.21.attn.blocks_21_attn_temperature',
#  'blocks.21.attn.mul_84',
#  'blocks.21.attn.softmax_21',
#  'blocks.21.attn.attn_drop',
#  'blocks.21.attn.matmul_43',
#  'blocks.21.attn.permute_86',
#  'blocks.21.attn.reshape_86',
#  'blocks.21.attn.proj',
#  'blocks.21.attn.proj_drop',
#  'blocks.21.mul_85',
#  'blocks.21.drop_path',
#  'blocks.21.add_64',
#  'blocks.21.blocks_21_gamma3',
#  'blocks.21.norm3',
#  'blocks.21.local_mp.getattr_48',
#  'blocks.21.local_mp.getitem_199',
#  'blocks.21.local_mp.getitem_200',
#  'blocks.21.local_mp.getitem_201',
#  'blocks.21.local_mp.permute_87',
#  'blocks.21.local_mp.reshape_87',
#  'blocks.21.local_mp.conv1',
#  'blocks.21.local_mp.act',
#  'blocks.21.local_mp.bn',
#  'blocks.21.local_mp.conv2',
#  'blocks.21.local_mp.reshape_88',
#  'blocks.21.local_mp.permute_88',
#  'blocks.21.mul_86',
#  'blocks.21.drop_path_1',
#  'blocks.21.add_65',
#  'blocks.21.blocks_21_gamma2',
#  'blocks.21.norm2',
#  'blocks.21.mlp.fc1',
#  'blocks.21.mlp.act',
#  'blocks.21.mlp.drop',
#  'blocks.21.mlp.fc2',
#  'blocks.21.mlp.drop_1',
#  'blocks.21.mul_87',
#  'blocks.21.drop_path_2',
#  'blocks.21.add_66',
#  'blocks.22.blocks_22_gamma1',
#  'blocks.22.norm1',
#  'blocks.22.attn.getattr_49',
#  'blocks.22.attn.getitem_202',
#  'blocks.22.attn.getitem_203',
#  'blocks.22.attn.getitem_204',
#  'blocks.22.attn.qkv',
#  'blocks.22.attn.floordiv_22',
#  'blocks.22.attn.reshape_89',
#  'blocks.22.attn.permute_89',
#  'blocks.22.attn.getitem_205',
#  'blocks.22.attn.getitem_206',
#  'blocks.22.attn.getitem_207',
#  'blocks.22.attn.normalize_44',
#  'blocks.22.attn.normalize_45',
#  'blocks.22.attn.transpose_23',
#  'blocks.22.attn.matmul_44',
#  'blocks.22.attn.blocks_22_attn_temperature',
#  'blocks.22.attn.mul_88',
#  'blocks.22.attn.softmax_22',
#  'blocks.22.attn.attn_drop',
#  'blocks.22.attn.matmul_45',
#  'blocks.22.attn.permute_90',
#  'blocks.22.attn.reshape_90',
#  'blocks.22.attn.proj',
#  'blocks.22.attn.proj_drop',
#  'blocks.22.mul_89',
#  'blocks.22.drop_path',
#  'blocks.22.add_67',
#  'blocks.22.blocks_22_gamma3',
#  'blocks.22.norm3',
#  'blocks.22.local_mp.getattr_50',
#  'blocks.22.local_mp.getitem_208',
#  'blocks.22.local_mp.getitem_209',
#  'blocks.22.local_mp.getitem_210',
#  'blocks.22.local_mp.permute_91',
#  'blocks.22.local_mp.reshape_91',
#  'blocks.22.local_mp.conv1',
#  'blocks.22.local_mp.act',
#  'blocks.22.local_mp.bn',
#  'blocks.22.local_mp.conv2',
#  'blocks.22.local_mp.reshape_92',
#  'blocks.22.local_mp.permute_92',
#  'blocks.22.mul_90',
#  'blocks.22.drop_path_1',
#  'blocks.22.add_68',
#  'blocks.22.blocks_22_gamma2',
#  'blocks.22.norm2',
#  'blocks.22.mlp.fc1',
#  'blocks.22.mlp.act',
#  'blocks.22.mlp.drop',
#  'blocks.22.mlp.fc2',
#  'blocks.22.mlp.drop_1',
#  'blocks.22.mul_91',
#  'blocks.22.drop_path_2',
#  'blocks.22.add_69',
#  'blocks.23.blocks_23_gamma1',
#  'blocks.23.norm1',
#  'blocks.23.attn.getattr_51',
#  'blocks.23.attn.getitem_211',
#  'blocks.23.attn.getitem_212',
#  'blocks.23.attn.getitem_213',
#  'blocks.23.attn.qkv',
#  'blocks.23.attn.floordiv_23',
#  'blocks.23.attn.reshape_93',
#  'blocks.23.attn.permute_93',
#  'blocks.23.attn.getitem_214',
#  'blocks.23.attn.getitem_215',
#  'blocks.23.attn.getitem_216',
#  'blocks.23.attn.normalize_46',
#  'blocks.23.attn.normalize_47',
#  'blocks.23.attn.transpose_24',
#  'blocks.23.attn.matmul_46',
#  'blocks.23.attn.blocks_23_attn_temperature',
#  'blocks.23.attn.mul_92',
#  'blocks.23.attn.softmax_23',
#  'blocks.23.attn.attn_drop',
#  'blocks.23.attn.matmul_47',
#  'blocks.23.attn.permute_94',
#  'blocks.23.attn.reshape_94',
#  'blocks.23.attn.proj',
#  'blocks.23.attn.proj_drop',
#  'blocks.23.mul_93',
#  'blocks.23.drop_path',
#  'blocks.23.add_70',
#  'blocks.23.blocks_23_gamma3',
#  'blocks.23.norm3',
#  'blocks.23.local_mp.getattr_52',
#  'blocks.23.local_mp.getitem_217',
#  'blocks.23.local_mp.getitem_218',
#  'blocks.23.local_mp.getitem_219',
#  'blocks.23.local_mp.permute_95',
#  'blocks.23.local_mp.reshape_95',
#  'blocks.23.local_mp.conv1',
#  'blocks.23.local_mp.act',
#  'blocks.23.local_mp.bn',
#  'blocks.23.local_mp.conv2',
#  'blocks.23.local_mp.reshape_96',
#  'blocks.23.local_mp.permute_96',
#  'blocks.23.mul_94',
#  'blocks.23.drop_path_1',
#  'blocks.23.add_71',
#  'blocks.23.blocks_23_gamma2',
#  'blocks.23.norm2',
#  'blocks.23.mlp.fc1',
#  'blocks.23.mlp.act',
#  'blocks.23.mlp.drop',
#  'blocks.23.mlp.fc2',
#  'blocks.23.mlp.drop_1',
#  'blocks.23.mul_95',
#  'blocks.23.drop_path_2',
#  'blocks.23.add_72',
#  'cls_token',
#  'expand',
#  'cat',
#  'cls_attn_blocks.0.norm1',
#  'cls_attn_blocks.0.attn.getattr_53',
#  'cls_attn_blocks.0.attn.getitem_220',
#  'cls_attn_blocks.0.attn.getitem_221',
#  'cls_attn_blocks.0.attn.getitem_222',
#  'cls_attn_blocks.0.attn.getitem_223',
#  'cls_attn_blocks.0.attn.q',
#  'cls_attn_blocks.0.attn.unsqueeze',
#  'cls_attn_blocks.0.attn.floordiv_24',
#  'cls_attn_blocks.0.attn.reshape_97',
#  'cls_attn_blocks.0.attn.permute_97',
#  'cls_attn_blocks.0.attn.k',
#  'cls_attn_blocks.0.attn.floordiv_25',
#  'cls_attn_blocks.0.attn.reshape_98',
#  'cls_attn_blocks.0.attn.permute_98',
#  'cls_attn_blocks.0.attn.mul_96',
#  'cls_attn_blocks.0.attn.v',
#  'cls_attn_blocks.0.attn.floordiv_26',
#  'cls_attn_blocks.0.attn.reshape_99',
#  'cls_attn_blocks.0.attn.permute_99',
#  'cls_attn_blocks.0.attn.transpose_25',
#  'cls_attn_blocks.0.attn.matmul_48',
#  'cls_attn_blocks.0.attn.softmax_24',
#  'cls_attn_blocks.0.attn.attn_drop',
#  'cls_attn_blocks.0.attn.matmul_49',
#  'cls_attn_blocks.0.attn.transpose_26',
#  'cls_attn_blocks.0.attn.reshape_100',
#  'cls_attn_blocks.0.attn.proj',
#  'cls_attn_blocks.0.attn.proj_drop',
#  'cls_attn_blocks.0.getitem_224',
#  'cls_attn_blocks.0.cat_1',
#  'cls_attn_blocks.0.cls_attn_blocks_0_gamma1',
#  'cls_attn_blocks.0.mul_97',
#  'cls_attn_blocks.0.drop_path',
#  'cls_attn_blocks.0.add_73',
#  'cls_attn_blocks.0.norm2',
#  'cls_attn_blocks.0.getitem_225',
#  'cls_attn_blocks.0.cls_attn_blocks_0_gamma2',
#  'cls_attn_blocks.0.mlp.fc1',
#  'cls_attn_blocks.0.mlp.act',
#  'cls_attn_blocks.0.mlp.drop',
#  'cls_attn_blocks.0.mlp.fc2',
#  'cls_attn_blocks.0.mlp.drop_1',
#  'cls_attn_blocks.0.mul_98',
#  'cls_attn_blocks.0.getitem_226',
#  'cls_attn_blocks.0.cat_2',
#  'cls_attn_blocks.0.drop_path_1',
#  'cls_attn_blocks.0.add_74',
#  'cls_attn_blocks.1.norm1',
#  'cls_attn_blocks.1.attn.getattr_54',
#  'cls_attn_blocks.1.attn.getitem_227',
#  'cls_attn_blocks.1.attn.getitem_228',
#  'cls_attn_blocks.1.attn.getitem_229',
#  'cls_attn_blocks.1.attn.getitem_230',
#  'cls_attn_blocks.1.attn.q',
#  'cls_attn_blocks.1.attn.unsqueeze_1',
#  'cls_attn_blocks.1.attn.floordiv_27',
#  'cls_attn_blocks.1.attn.reshape_101',
#  'cls_attn_blocks.1.attn.permute_100',
#  'cls_attn_blocks.1.attn.k',
#  'cls_attn_blocks.1.attn.floordiv_28',
#  'cls_attn_blocks.1.attn.reshape_102',
#  'cls_attn_blocks.1.attn.permute_101',
#  'cls_attn_blocks.1.attn.mul_99',
#  'cls_attn_blocks.1.attn.v',
#  'cls_attn_blocks.1.attn.floordiv_29',
#  'cls_attn_blocks.1.attn.reshape_103',
#  'cls_attn_blocks.1.attn.permute_102',
#  'cls_attn_blocks.1.attn.transpose_27',
#  'cls_attn_blocks.1.attn.matmul_50',
#  'cls_attn_blocks.1.attn.softmax_25',
#  'cls_attn_blocks.1.attn.attn_drop',
#  'cls_attn_blocks.1.attn.matmul_51',
#  'cls_attn_blocks.1.attn.transpose_28',
#  'cls_attn_blocks.1.attn.reshape_104',
#  'cls_attn_blocks.1.attn.proj',
#  'cls_attn_blocks.1.attn.proj_drop',
#  'cls_attn_blocks.1.getitem_231',
#  'cls_attn_blocks.1.cat_3',
#  'cls_attn_blocks.1.cls_attn_blocks_1_gamma1',
#  'cls_attn_blocks.1.mul_100',
#  'cls_attn_blocks.1.drop_path',
#  'cls_attn_blocks.1.add_75',
#  'cls_attn_blocks.1.norm2',
#  'cls_attn_blocks.1.getitem_232',
#  'cls_attn_blocks.1.cls_attn_blocks_1_gamma2',
#  'cls_attn_blocks.1.mlp.fc1',
#  'cls_attn_blocks.1.mlp.act',
#  'cls_attn_blocks.1.mlp.drop',
#  'cls_attn_blocks.1.mlp.fc2',
#  'cls_attn_blocks.1.mlp.drop_1',
#  'cls_attn_blocks.1.mul_101',
#  'cls_attn_blocks.1.getitem_233',
#  'cls_attn_blocks.1.cat_4',
#  'cls_attn_blocks.1.drop_path_1',
#  'cls_attn_blocks.1.add_76',
#  'norm',
#  'getitem_234',
#  'head']

# %%
from skimage.transform import resize
import math
import torch.nn.functional as F

return_nodes = {
    'cls_attn_blocks.0.attn.matmul_48': 'attn'
}

feat_ext = create_feature_extractor(
    model, return_nodes=return_nodes,
    tracer_kwargs={'leaf_modules': [PositionalEncodingFourier]})

ix = 0

with torch.no_grad():
    out = feat_ext(inps[ix])#['attn']
    # Softmax with temperature
    heat_maps = torch.softmax(out/5, -1)
    # Remove class token
    heat_maps = heat_maps[..., 1:]
    # Deflatten
    edge_length = int(math.sqrt(heat_maps.shape[-1]))
    heat_maps = heat_maps.reshape(1, -1, edge_length, edge_length)
    # Resize to image shape
    heat_maps = F.interpolate(heat_maps, imgs[ix].shape[:2], mode='bicubic')
    heat_maps = list(heat_maps[0].squeeze(1).numpy())

import numpy as np
import matplotlib.cm as cm

def overlay_heat_map(
        img: np.ndarray, heat_map: np.ndarray, color=(255, 0, 0)) -> np.ndarray:
    """
    heat_map values should be in [0, 1]
    """
    assert (heat_map.shape[0] == img.shape[0]) and (heat_map.shape[1] == img.shape[1])
    # overlay = np.tile(color, (*img.shape[:2], 1))
    overlay = cm.hot(heat_map)[..., :3] * 255
    heat_map = heat_map[..., None].repeat(3, -1)
    img = (img * (1 - heat_map) + overlay * heat_map).astype(np.uint8)
    return img
    # return overlay.astype(np.uint8)


# Scale pixels
heat_maps = [(hm - hm.min()) / (hm.max() - hm.min()) for hm in heat_maps]
heat_map_imgs = [overlay_heat_map(imgs[ix], heat_map) for heat_map in heat_maps]
heat_map_imgs.insert(4, imgs[ix])
heat_map_imgs.insert(0, imgs[ix])
show_images(heat_map_imgs, per_row=5, imsize=(5, 5));
# Out:
# torch.Size([1, 8, 1, 2305])

# %%
# Out:
# 48
